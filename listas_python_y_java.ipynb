# %% [markdown]
# <a href="https://colab.research.google.com/github/lsanchez595-star/PROGCOMP-A2026/blob/main/listas_python_y_java.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Quiero saber cuántos n estudiantes sacan más del promedio :)

# %%
n1=int(input("Ingrese su primera nota:"))
n2=int(input("Ingrese su segunda nota:"))
n3=int(input("Ingrese su tercera nota:"))

condición=n1+n2+n3/3

for i in range (condicion):
  i > condicion
print(f"Estas son las notas mayores al promedio {i}")

# %%
suma=0
c=0
n=int(input("Ingrese la cantidad de estudiantes"))
for i in range(n)
nota=int(input(""))

# %% [markdown]
# #LISTAS
# Es una colección de elementos que cumple las siguientes características.
# 1. Mutable
# 2. Es que tiene index
#
# ##Creación de listas
# nombre_lista=[]
#
# Existen ds formas de crear una lista:
# 1. Por extensión: Se nombra uno a uno los elementos
# 2. Por comprensión: Se nombra la característica general
# 3. Sus elementos están separados por comas

# %%
galleta=["angeles", "dinosaurios", "diablitos"]
cant_galletas=[2,2,3]

# %% [markdown]
# ##Forma manual
# Sintaxis
# ```
# nombre_lista=[posición de interés]
# ```

# %%
galleta[2]

# %%
cant_galletas[2]

# %%
##Forma automática
for caja in range(3):
  print(f"{galleta[caja]}:{cant_galletas[caja]}")

# %%
salarios=[1000,2000,1500,4000,7000]
promedio=sum(salarios)/len(salarios)
mayores=[]

for salario in salarios:
  if salario>promedio:
    mayores.append(salario)
print("promedio:", promedio)
print("cantidad que gana más:", len(mayores))
print("Salarios mayores al promedio:",mayores)

# %%
productos=["pan","leche","arroz","vinagre","frutas","aceite"]
precios=[4000,12000,13000,7000,8000,10000]
print("Este es el menú de la tienda")
for i in range(len(productos)):
  print(i+1, productos[i],"-",precios[i])
opcion=int(input("seleccione un productos:"))
print("Elegiste:", productos[opcion-1])
print("precios:", precios[opcion-1])

# %%
numeros=[4,10,23,15,20,18]
n=int(input("ingrese el numero n:"))
contador=0
for num in numeros:
  if num%n==0:
    contador+=1
print("Cantidad de multiplos de", n,":", contador)

# %%
lluvia=input("¿Esta lloviendo?")
if lluvia=="si":
  print("cierra las ventanas")
else:
  if lluvia=="un poquito":
     print("si vas a salir lleva sombrilla")
  else:
        print("resguardate")

# %% [markdown]
# ##OPERACIONES DE LAS LISTAS
# 1. Recorrer elementos de la lista
# 2. Verificar si eiste el elemento de la lista
# 3. Conocer la posición de un elemento de la lista
# 4. Conocer en que elemento se encuentra en una posición de la lista
# 5. Eliminar elementos de la lista
# 6. Mutabilidad de la lista

# %% [markdown]
# ###1. Recorrer elementos de la lista

# %%
#Función len: Retorna la longitud de un dato
len(galleta)

# %%
for galleta in range(len(galleta)):
  print(galleta[galleta])

# %%
for i in galleta:
  print(i)

# %%
galleta

# %% [markdown]
# ##2. Verificar si existe un elemento de la lista

# %%
galleta=["angelitos","dinosaurios","diablitos"]

# %%
user=input("Ingrese la galleta que quiere comprar: ")
for i in galleta:
 if user=="angelitos": print("Si hay")
 elif user=="dinosaurios": print("Si hay")
 elif user=="diablitos": print("Si hay")
 else: print("No hay")
 break

# %%
for i in galleta:
  if galleta==user:
    print("Si hay")
    break
else: print("No hay")

# %%
if user in galleta: print("Si hay")
else: print("No hay")

# %%
print(f"Si hay" if user in galleta else "No hay")

# %%
##Calcular quienes son los que sacaron más promedio, y quién fu al mayor nota y cuánto
estudiantes=["Luna","Kamyla","Maximiliano","Oscar","Samuel","Juan Sebastián", "Danna","Isabella","Sopita","Nayla","Sara"]
notas=[4,4,1,4,4,2,1,5,4,1]
for i in range(10):
   print(f"{i+1}.{estudiantes[i]}:{notas[i]}")
promedio=sum(notas)/10
print(promedio)
# Out:
# 1.Luna:4
# 2.Kamyla:4
# 3.Maximiliano:1
# 4.Oscar:4
# 5.Samuel:4
# 6.Juan Sebastián:2
# 7.Danna:1
# 8.Isabella:5
# 9.Sopita:4
# 10.Nayla:1
# 3.0

# %%
suma=0
for i in notas:
   suma+=i
promedio=suma/len(estudiantes)
print(promedio)
# Out:
# 2.727272727272727

# %%
candidatos=["Kamyla", "Luna","Camila","Juan Sebastian", "Samuel"]
votos=[0, 0, 0, 0, 0]
n=int(input("cuantos usuarios van a votar"))
for i in range(len(candidatos)):
  print(i candidatos[i])
voto=input("ingrese su voto(numero de su candidato: )")
votos[voto]=votos[voto]+1
print("ganadores primera vuelta: ")
for i in range (len(candidatos)):
  print(candidatos[i] : "votos":votos[i])

ganador1=votos.index(max(votos))
ganador2=votos.index(max(votos))
print(f"pasan a la segunda vuelta {ganador1} y {ganador 2}")
# Out:
#   File "/tmp/ipykernel_523/607484234.py", line 5
#     print(i candidatos[i])
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
n=[1, 5, 5, 2, 3, 5]
n.index(max(n))
# Out:
# 1

# %%
for i in range(len(n)):
  if max(n)== n[i]:
    print (i)
# Out:
# 1
# 2
# 5
