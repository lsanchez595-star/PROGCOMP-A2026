# %% [markdown]
# <a href="https://colab.research.google.com/github/lsanchez595-star/PROGCOMP-A2026/blob/main/prueba%20python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Te damos la bienvenida a Colab

# %%
a = float(input("Digite a: "))
b = float(input("Digite b: "))
c = float(input("Digite c: "))

total1 = (-b + ((b**2 - 4*a*c)**0.5)) / (2*a)
total2 = (-b - ((b**2 - 4*a*c)**0.5)) / (2*a)
print(f"x1={total1}, x2={total2}")
# Out:
# Digite a: 1
# Digite b: 2
# Digite c: 3
# x1=(-0.9999999999999999+1.4142135623730951j), x2=(-1-1.4142135623730951j)

# %%
num=float(input("Digite numero a evaluar: "))

if num % 2 == 0:
    print("Es par")
else:
    print("Es impar")
# Out:
# Digite numero a evaluar: 4
# Es par

# %%
año = int(input("Digite el año a evaluar: "))

if (año % 4 == 0 and año % 100 != 0) or (año % 400 == 0):
    print("Es un año bisiesto")
else:
    print("No es un año bisiesto")
# Out:
# Digite el año a evaluar: 2100
# No es un año bisiesto

# %%
n1=float(input("Digite el primer numero: "))
n2=float(input("Digite el segundo numero: "))
n3=float(input("Digite el tercer numero: "))
if n1>n2>n3:
  print(f"{n1}")
elif n2>n1>n3:
    print(f"{n2}")
else:
      print(f"El mayor numero es: {n3}")
# Out:
# Digite el primer numero: 4
# Digite el segundo numero: 5
# Digite el tercer numero: 3
# 5.0

# %%
l1=float(input("ingrese lado 1:"))
l2=float(input("ingrese lado 2:"))
l3=float(input("ingrese lado 3:"))
if l1==l2 and l2==l3 and l1==l3:
 print("equilatero")
elif l1==l2 or l2==l3 or l1==l3:
 print("isosceles")
else:
  print("escaleno")

# %%
nombre=(input("Digite su nombre: "))
kg=float(input("digite su peso:"))
h=float(input("digite su altura:"))
imc=float
imc=(kg/(h*h))
if imc<18.5:
 print(f"{nombre}\n Categoria:bajo peso \n Concentrese en alimentos ricos en nutrientes y calorias e intente consumir mas calorias de las que quema :)")
elif 18.5<imc<24.9:
 print(f"{nombre}\n Categoria:peso normal\n Siga llevando una dieta balanceada con actividad fisica frecuente")
elif 25<imc<29.9:
 print(f"{nombre}\n Categoria:sobrepeso\n Aumente su actividad fisica caminando o practicando algun deporte y consulte a un nutrisionista para mejorar su dieta ")
elif imc>=30:
  print(f"{nombre}\n Categoria:obesidad \n Mejore sus habitos alimenticios y haga mas actividad fisica")
else:
  print("error")
# Out:
# Digite su nombre: luna
# digite su peso:69
# digite su altura:1.32
# luna
#  Categoria:obesidad
#  Mejore sus habitos alimenticios y haga mas actividad fisica

# %%
n1=float(input("ingrese el primer numero de la operacion"))
n2=float(input("ingrese el segundo numero de la operacion"))
signo=(input("ingrese el signo que va a utilizar"))
if signo=="-":
    print(n1-n2)
elif signo== "+":
    print(n1+n2)
elif signo== "*":
    print(n1*n2)
elif signo== "/":
    print(n1/n2)
else:
    print(error)
# Out:
# ingrese el primer numero de la operacion2
# ingrese el segundo numero de la operacion3
# ingrese el signo que va a utilizar*
# 6.0

# %%
nota = float(input("Digite la nota (0-100): "))

if nota < 0 or nota > 100:
    print("Nota inválida")
elif nota >= 90:
    print("Clasificación: A")
elif nota >= 80:
    print("Clasificación: B")
elif nota >= 70:
    print("Clasificación: C")
elif nota >= 60:
    print("Clasificación: D")
else:
    print("Clasificación: F")

# %%
n=int(input("Digite un numero del 1 al 7: "))
if n==1:
  print("Lunes")
elif n==2:
  print("martes")
elif n==3:
  print("miercoles")
elif n==4:
    print("jueves")
elif n==5:
    print("viernes")
elif n==6:
      print("sabado")
elif n==7:
        print("domingo")
else:
          print("error")
# Out:
# Digite un numero del 1 al 7: 8
# error

# %%
a = float(input("Digite el lado a: "))
b = float(input("Digite el lado b: "))
c = float(input("Digite el lado c: "))

if a + b > c and a + c > b and b + c > a:
    print("Si puede formar un triángulo")
    if a == b and b == c:
        print("triangulo Equilátero")
    elif a == b or a == c or b == c:
        print("triangulo Isósceles")
    else:
        print("triangulo Escaleno")
else:
    print("No puede formar un triángulo")
# Out:
# Digite el lado a: 3
# Digite el lado b: 4
# Digite el lado c: 5
# Si puede formar un triángulo
# triangulo Escaleno
